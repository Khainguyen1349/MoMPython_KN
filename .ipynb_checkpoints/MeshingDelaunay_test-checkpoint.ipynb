# %%
import numpy as np
from scipy.spatial import Delaunay#, ConvexHull
import matplotlib.pyplot as plt
from meshlib import *

# %% [markdown]
# ## Define a hull
# Define the shape on the negative side of Y axis

# %%
hull_bound_points = np.array([[-5,10],[-6,10],[-5,11],[-6,11]])*4
mesh_resolution = 4
tri = creatHull(hull_bound_points,mesh_resolution)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[10,8],[-10,8],[10,10],[-10,10]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[-5,10],[-6,10]])*4
tri = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[10,8],[-10,8],[10,1],[-10,1]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[-10,8],[10,8]])*4
tri = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[-9,10],[-10,10],[-9,20],[-10,20]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[-10,10],[-9,10]])*4
tri = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[-6,11],[-5,11],[-6,20],[-5,20]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[-6,11],[-5,11]])*4
tri = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[-10,20],[10,20],[-10,21],[10,21]])*4
mesh_resolution_ext = 4
commonEdge1 = np.array([[-10,20],[-9,20]])*4
commonEdge2 = np.array([[-6,20],[-5,20]])*4
tri = closeLoopHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge1,commonEdge2)
# plot
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[8,14],[10,14],[8,20],[10,20]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[18,20],[20,20]])*4
tri = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
triY = mirror2DShapes(tri,"Y",4,True)
plt.triplot(triY.points[:,0], triY.points[:,1], triY.simplices)
plt.show()
# Out:
# Min Y: 4.0
# [[-40   0]
#  [ 40   0]
#  [-40   4]
#  [ 40   4]]
# 4
# [[-40   4]
#  [ 40   4]]
# [[-40   0]
#  [ 40   0]]

# %% [markdown]
# line = 4
# mirrorEdge = np.array([[int(np.min(tri.points[np.where(tri.points[:,1] == line),0])),line],
#                        [int(np.max(tri.points[np.where(tri.points[:,1] == line),0])),line]])
# overlappedPoints(tri.points, mirrorEdge)
# pp_list = overlappedPointsPosition(tri.points,overlappedPoints(tri.points, mirrorEdge))
# tri_temp = Delaunay_temp(tri.points*np.array([1,-1]) + np.array([0,2*line]), tri.simplices)
# for i in range(len(pp_list)):
#     tri_temp.deletePoint(pp_list[i]-i)
#
# tri = addSeparatedShapes(tri, tri_temp)
#
# hull_bound_points_ext = np.array([[mirrorEdge[0,0],int(max(tri_temp.points[:,1]))],
#                                   [mirrorEdge[1,0],int(max(tri_temp.points[:,1]))],
#                                   [mirrorEdge[0,0],mirrorEdge[0,1]],
#                                    [mirrorEdge[1,0],mirrorEdge[1,1]]])
# mesh_resolution_ext = int(min([np.abs(tri.points[pp_list[0],0] - tri.points[i,0]) for i in pp_list[1:]]))
# commonEdge1 = mirrorEdge
# commonEdge2 = np.array([[mirrorEdge[0,0],int(max(tri_temp.points[:,1]))],[mirrorEdge[1,0],int(max(tri_temp.points[:,1]))]])
# tri = closeLoopHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge1,commonEdge2)
# plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
# plt.show()

# %%
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
line = -40
mirrorOverO = True
mirrorEdge = np.array([[line,int(np.min(tri.points[np.where(tri.points[:,0] == line),1]))],
                        [line,int(np.max(tri.points[np.where(tri.points[:,0] == line),1]))]])
overlappedPoints(tri.points, mirrorEdge)
pp_list = overlappedPointsPosition(tri.points,overlappedPoints(tri.points, mirrorEdge))
if mirrorOverO:
    tri_temp = Delaunay_temp(tri.points*np.array([-1,-1]) + np.array([2*line,0]), tri.simplices)
else:
    tri_temp = Delaunay_temp(tri.points*np.array([-1,1]) + np.array([2*line,0]), tri.simplices)
for i in range(len(pp_list)):
    tri_temp.deletePoint(pp_list[i]-i)

plt.triplot(tri_temp.points[:,0], tri_temp.points[:,1], tri_temp.simplices)
plt.show()
# Out:
# [[-44   4]
#  [-40   4]
#  [-44  84]
#  [-40  84]]
# 4
# [[-40   4]
#  [-40  84]]
# [[-44   4]
#  [-44  84]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-6505b20c75c7> in <module>
#      26                         [int(max(tri_temp.points[:,0])),mirrorEdge[1,1]]])
#      27 print(commonEdge2)
# ---> 28 tri = closeLoopHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge1,commonEdge2)
#
# ~\Documents\GitHub\MoMPython_KN\meshlib.py in closeLoopHull(tri_origine, hull_bound_points_ext, mesh_resolution_ext, commonEdge1, commonEdge2)
#      92
#      93     # find overlapped point on tri_original
# ---> 94     olP = np.concatenate((overlappedPoints(tri_origine.points, commonEdge1), overlappedPoints(tri_origine.points, commonEdge2)), axis=0)
#      95     # find the positions of the ovelapped points
# ...

# %%
tri = addSeparatedShapes(tri, tri_temp)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[int(max(tri_temp.points[:,0])),mirrorEdge[0,1]],
                                    [mirrorEdge[0,0],mirrorEdge[0,1]],
                                    [int(max(tri_temp.points[:,0])),mirrorEdge[1,1]],
                                    [mirrorEdge[1,0],mirrorEdge[1,1]]])
print(hull_bound_points_ext)
mesh_resolution_ext = int(min([np.abs(tri.points[pp_list[0],1] - tri.points[i,1]) for i in pp_list[1:]]))
print(mesh_resolution_ext)
commonEdge1 = mirrorEdge
print(commonEdge1)
commonEdge2 = np.array([[int(max(tri_temp.points[:,0])),mirrorEdge[0,1]],
                        [int(max(tri_temp.points[:,0])),mirrorEdge[1,1]]])
print(commonEdge2)
tri = closeLoopHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge1,commonEdge2)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %% [markdown]
# hull_bound_points_ext = np.array([[-15,1],[-10,1],[-15,10],[-10,10]])*4
# mesh_resolution_ext = 4
# commonEdge = np.array([[-10,1],[-10,10]])*4
# tri = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
# plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
# plt.show()

# %% [markdown]
# triX = mirror2DShapes(tri,"X",-40,True)
# plt.triplot(triX.points[:,0], triX.points[:,1], triX.simplices)
# plt.show()
