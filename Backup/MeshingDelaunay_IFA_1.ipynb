# %%
import numpy as np
from scipy.spatial import Delaunay#, ConvexHull
import matplotlib.pyplot as plt
from meshlib import *

# %% [markdown]
# ## Define a hull
# Define the shape on the negative side of Y axis

# %%
hull_bound_points = np.array([[10,8],[-10,8],[10,10],[-10,10]])*4
mesh_resolution = 2
tri = creatHull(hull_bound_points,mesh_resolution)
plt.triplot(tri.points[:,0], tri.points[:,1], tri.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[10,8],[-10,8],[10,0],[-10,0]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[-10,8],[10,8]])*4
tri_final = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
plt.show()
# Out:
# [[-40.  32.]
#  [-38.  32.]
#  [-36.  32.]
#  [-34.  32.]
#  [-32.  32.]
#  [-30.  32.]
#  [-28.  32.]
#  [-26.  32.]
#  [-24.  32.]
#  [-22.  32.]
#  [-20.  32.]
#  [-18.  32.]
#  [-16.  32.]
#  [-14.  32.]
#  [-12.  32.]
#  [-10.  32.]
#  [ -8.  32.]
#  [ -6.  32.]
#  [ -4.  32.]
#  [ -2.  32.]
#  [  0.  32.]
#  [  2.  32.]
#  [  4.  32.]
#  [  6.  32.]
#  [  8.  32.]
#  [ 10.  32.]
#  [ 12.  32.]
#  [ 14.  32.]
#  [ 16.  32.]
#  [ 18.  32.]
#  [ 20.  32.]
#  [ 22.  32.]
#  [ 24.  32.]
#  [ 26.  32.]
#  [ 28.  32.]
#  [ 30.  32.]
#  [ 32.  32.]
#  [ 34.  32.]
#  [ 36.  32.]
#  [ 38.  32.]
#  [ 40.  32.]]

# %% [markdown]
# # Hull extension

# %%
hull_bound_points_ext = np.array([[10,8],[-10,8],[10,0],[-10,0]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[8,0],[-8,0]])*4
tri_final = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
# plot
plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
plt.show()
# Out:
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6f65b52d8406> in <module>
#       2 mesh_resolution_ext = 4
#       3 commonEdge = np.array([[8,0],[-8,0]])*4
# ----> 4 tri_final = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
#       5 # plot
#       6 plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
#
# ~\Documents\GitHub\MoMPython_KN\meshlib.py in extentHull(tri_origine, hull_bound_points_ext, mesh_resolution_ext, commonEdge)
#      70     # add the ovelapped points in the original tri
#      71     if len(olPP2) > 0:
# ---> 72         mesh_ini = np.append(olP,mesh_ini_del, axis=0)
#      73     # check if inside hull
#      74     mesh_add = np.array([p_ for p_ in mesh_ini if hull_bound_ext.find_simplex(p_)>=0])
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in append(arr, values, axis)
#    4669         values = ravel(values)
#    4670         axis = arr.ndim-1
# -> 4671     return concatenate((arr, values), axis=axis)
#    4672
#    4673
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
hull_bound_points_ext = np.array([[10,8],[-10,8],[10,0],[-10,0]])*4
mesh_resolution_ext = 4
commonEdge = np.array([[8,0],[-8,0]])*4
tri_final = extentHull(tri,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
# plot
plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
plt.show()

# %% [markdown]
# # Add small strip-line

# %%
hull_bound_points_ext = np.array([[-10,20],[-8,20],[-10,10],[-8,10]])
mesh_resolution_ext = 1
commonEdge = np.array([[-10,10],[-8,10]])

tri_final = extentHull(tri_final,hull_bound_points_ext,mesh_resolution_ext,commonEdge)

# %%
# plot
plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
plt.show()

# %% [markdown]
# # Add small strip-line

# %%
hull_bound_points_ext = np.array([[-6,10],[-4,10],[-6,20],[-4,20]])
mesh_resolution_ext = 1
commonEdge = np.array([[-6,10],[-4,10]])

tri_final = extentHull(tri_final,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
# plot
plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[-10,20],[10,20],[-10,22],[10,22]])
mesh_resolution_ext = 1
commonEdge1 = np.array([[-10,20],[-8,20]])
commonEdge2 = np.array([[-6,20],[-4,20]])

tri_final = closeLoopHull(tri_final,hull_bound_points_ext,mesh_resolution_ext,commonEdge1,commonEdge2)
# plot
plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
plt.show()

# %%
hull_bound_points_ext = np.array([[8,14],[10,14],[8,20],[10,20]])
mesh_resolution_ext = 1
commonEdge = np.array([[8,20],[10,20]])

tri_final = extentHull(tri_final,hull_bound_points_ext,mesh_resolution_ext,commonEdge)
# plot
plt.triplot(tri_final.points[:,0], tri_final.points[:,1], tri_final.simplices)
plt.show()
